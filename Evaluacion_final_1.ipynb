# %% [markdown]
# Ejercicio
# A lo largo de esta evaluación tendrás que crear una clase llamada TiendaOnline que cumpla los
# siguientes requisitos:
# La clase TiendaOnline debe tener los siguientes atributos:
#
# 1. inventario (lista de diccionarios): Un atributo para almacenar los productos en el inventario.
# Cada producto debe ser representado como un diccionario con las siguientes claves:
# 'nombre', 'precio', y 'cantidad'.
#  Al principio deberá ser una lista vacía. Ejemplo de
# como debería ser:

# %%
#la clase tienda online debe tener los siguientes atributos
#inventario (lista de diccionarios): Un atributo para almacenar los productos en el inventario.
#Cada producto debe ser representado como un diccionario con las siguientes claves:
#'nombre', 'precio', y 'cantidad'.
class TiendaOnline:
    def __init__(self):
        self.inventario  = []
        self.ventas_totales = 0
#agregar producto
    def agregar_producto (self , nombre, precio , cantidad):
        for producto in self.inventario: #recorre el inventario
            if producto["nombre"]==nombre: #para saber si ya existen el o los productos
                producto ["cantidad"] += cantidad
                return
        agregar_nuevo_producto = {"nombre": nombre , 
                                  "precio": f"$ {precio}" , # se hace la funcion precio para que muestre el signo en el precio
                                  "cantidad": cantidad}
        self.inventario.append(agregar_nuevo_producto)#si no existe agrega un nuevoproducto

# %%
tienda = TiendaOnline()

tienda.agregar_producto ("Camisa", 20,40)
tienda.agregar_producto ("Pantalon", 30,30)
tienda.agregar_producto ("Zapatos",50,40)
tienda.agregar_producto ("camisa",20,50)
print (tienda.inventario) #imprime el inventario
# Out:
# [{'nombre': 'Camisa', 'precio': '$ 20', 'cantidad': 40}, {'nombre': 'Pantalon', 'precio': '$ 30', 'cantidad': 30}, {'nombre': 'Zapatos', 'precio': '$ 50', 'cantidad': 40}, {'nombre': 'camisa', 'precio': '$ 20', 'cantidad': 50}]

# %% [markdown]
# 2. ver_inventario(self): Muestra el inventario de productos con sus detalles.
# Utiliza un bucle for para recorrer el inventario.
#
# 2.1 Imprime los detalles (nombre, precio, cantidad) de cada producto.
# Debería verse:
# Nombre: Camisa, Precio: $20, Cantidad: 50
# Nombre: Pantalón, Precio: $30, Cantidad: 30
# Nombre: Zapatos, Precio: $50, Cantidad: 40
# Nombre: Camisa, Precio: $20, Cantidad: 50

# %%
for producto in tienda.inventario:
    print (producto)
# Out:
# {'nombre': 'Camisa', 'precio': '$ 20', 'cantidad': 40}
# {'nombre': 'Pantalon', 'precio': '$ 30', 'cantidad': 30}
# {'nombre': 'Zapatos', 'precio': '$ 50', 'cantidad': 40}
# {'nombre': 'camisa', 'precio': '$ 20', 'cantidad': 50}

# %% [markdown]
# 3. buscar_producto(self, nombre): Busca un producto en el inventario por nombre y muestra sus
# detalles si se encuentra. Debe recibir el nombre del producto como parámetro.
# Utiliza un bucle for para recorrer el inventario.
# Compara los nombres de los productos con el nombre proporcionado.
# Si se encuentra el producto, imprime sus detalles.
# Debe mostrar:
# Nombre: Camisa, Precio: $20, Cantidad: 40

# %%
inventario_1 = [{"nombre":"camisa","precio": 20,"cantidad":40},{"nombre":"pantalon","precio":30,"cantidad":50},{"nombre":"zapatos","precio":30}]

# %%
class TiendaOnline:
    def __init__(self,nombre):
        self.inventario = [{"nombre":"camisa","precio": 20,"cantidad":40},{"nombre":"pantalon","precio":30,"cantidad":50},{"nombre":"zapatos","precio":30, "cantidad":10}]
    def buscar_producto(self,nombre):
     producto_encontrado = None
     for producto in self.inventario:
          if producto ["nombre"].lower()==nombre.lower():
              producto_encontrado =producto
              break
          if producto_encontrado:
              print ("producto_encontrado")
              print ("nombre:",producto_encontrado["nombre"])
              print ("Precio:",producto_encontrado["precio"])
              print ("cantidad:",producto_encontrado["cantidad"])
     else: ("El producto no esta")

# %%
tienda = TiendaOnline
Tienda.buscar_producto("camisa")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[231], line 2
#       1 tienda = TiendaOnline
# ----> 2 Tienda.buscar_producto("camisa")
#
# NameError: name 'Tienda' is not defined

# %% [markdown]
# 4.actualizar_stock(self, nombre, cantidad): Actualiza el stock de un producto en el
# inventario. Debe recibir el nombre del producto y la cantidad a agregar o quitar como parámetros.
# Utiliza un bucle for para recorrer el inventario.
# 4.1 Busca el producto por nombre.
# Actualiza la cantidad según la entrada del usuario.
# Si el producto no esta en el inventario muestra un mensaje indicándolo.

# %%
class TiendaOnline:# volvi hacer una clase par ver si asi funcionaba
    def __init__(self,inventario):
        self.inventario=inventario
        pass
    def actualizar_stock(self,nombre, cantidad):
        for producto in inventario_1:
            if producto["nombre"].lower()==nombre.lower():
                producto["cantidad"]+= cantidad
            print(f"inventario actualizado ,nuevo producto en inventario {producto["nombre"]}:{producto["cantidad"]}")
        print ("el producto no esta en el inventario")

# %%
tienda = TiendaOnline([{"nombre": "camisa","cantidad": 10}])
tienda.actualizar_stock("pantalon",15) #esto no esta bien no da la cantidad correcta
# Out:
# inventario actualizado ,nuevo producto en inventario camisa:40
# inventario actualizado ,nuevo producto en inventario pantalon:65
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[233], line 2
#       1 tienda = TiendaOnline([{"nombre": "camisa","cantidad": 10}])
# ----> 2 tienda.actualizar_stock("pantalon",15) #esto no esta bien no da la cantidad correcta
#
# Cell In[232], line 9, in TiendaOnline.actualizar_stock(self, nombre, cantidad)
#       7     if producto["nombre"].lower()==nombre.lower():
#       8         producto["cantidad"]+= cantidad
# ----> 9     print(f"inventario actualizado ,nuevo producto en inventario {producto["nombre"]}:{producto["cantidad"]}")
#      10 print ("el producto no esta en el inventario")
#
# KeyError: 'cantidad'

# %% [markdown]
# 5. eliminar_producto(self, nombre): Elimina un producto del inventario por nombre. Debe
# recibir el nombre del producto como parámetro.
# Utiliza un bucle for para recorrer el inventario.
# Busca el producto por nombre.
# Elimina el producto del inventario si existe.
# Si el producto no esta en el inventario muestra un mensaje indicándolo.5.

# %%
def eliminar_producto (self,nombre):
    for producto in self.inventario:
        if producto["nombre"].lower()==nombre.lower():
            self.inventario.remove(producto)
            print (f"producto '{nombre}'Eliminado del inventario.")
            return
    print("el producto no esta en inventario")

# %%
print (inventario) #print de control para ver que si hay inventario
# Out:
# [{'nombre': 'camisa', 'precio': 20, 'cantidad': 40}, {'nombre': 'pantalon', 'precio': 30, 'cantidad': 50}, {'nombre': 'zapatos', 'precio': 30}]

# %%
tienda.eliminar_producto("camisa")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[236], line 1
# ----> 1 tienda.eliminar_producto("camisa")
#
# AttributeError: 'TiendaOnline' object has no attribute 'eliminar_producto'

# %% [markdown]
# 6. calcular_valor_inventario(self): Calcula y muestra el valor total del inventario.
# Utiliza un bucle for para calcular el valor total del inventario.
# Itera a través del inventario y suma el valor de cada producto (precio x cantidad). Es decir,
# calcula el valor total del inventario.
# Ejemplo:
# si tenemos 5 camisas que valen 5 euros
#  y 10 calcetines que valen 1 euro
#  este método te tiene que devolver: 35 euros
# evaluacion-finalv_2.md 2024-12-16
# 3 / 5
# valor_camisas = 5 * 5
# valor_calcetines = 10 * 1
# valor_camisas + valor_calcetines = 35
# Instrucciones Adicionales:

# %%
class TiendaOnline:
    def __init__(self):
        self.inventario_1 = inventario
        
    def calcular_valor_inventario(self, inventario_1):
        valor_total = 0
        for producto in self.inventario:
            valor_producto = producto ["precio"] * producto ["cantidad"]
            valor_total += valor_producto
        print (f"El valor total de inventario es :{valor_total}euros")
        return valor_total

# %%
print (inventario_1) #print de control para ver si hay variable inventrio_1
# Out:
# [{'nombre': 'camisa', 'precio': 20, 'cantidad': 40}, {'nombre': 'pantalon', 'precio': 30, 'cantidad': 65}, {'nombre': 'zapatos', 'precio': 30}]

# %%
tienda =TiendaOnline ()
tienda.calcular_valor_inventario()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[213], line 2
#       1 tienda =TiendaOnline ()
# ----> 2 tienda.calcular_valor_inventario()
#
# TypeError: TiendaOnline.calcular_valor_inventario() missing 1 required positional argument: 'inventario'
